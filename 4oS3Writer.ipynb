# %%
import os
import openai
import logging
import time
import requests
from openai import OpenAI, APIConnectionError, RateLimitError, APIError

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# OpenAI API setup
openai_api_key = os.getenv('OPENAI_API_KEY')
if not openai_api_key:
    logging.error("OpenAI API key not found. Please set the 'OPENAI_API_KEY' environment variable.")
    exit(1)

client = OpenAI(api_key=openai_api_key)

output_directory = os.path.join('4o Blog Raw Text Matt')

# Ensure the output directory exists
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

def fetch_summary_from_s3(file_number):
    url = f"https://edx-ai-class.s3.us-west-1.amazonaws.com/RAW_TEXT/article_{file_number}.txt"
    try:
        response = requests.get(url)
        response.raise_for_status()
        content = response.text.strip()
        if not content:
            logging.error(f"File is empty: {url}")
            return None
        return content
    except requests.exceptions.RequestException as e:
        logging.error(f"Failed to fetch file from {url}: {str(e)}")
        return None

def generate_blog_post(summary, retries=2):
    system_prompt = """You are a highly skilled content writer with expertise in creating engaging and informative blog posts. Your task is to expand upon provided texts, transforming them into well-structured and captivating articles. Follow the detailed instructions and maintain a consistent, engaging tone throughout the content.

Instructions for generating a blog post:
1. **Introduction**: Craft a compelling introduction that introduces the topic and grabs the reader's attention. Set the context for the discussion and hint at what the reader will gain from the post.
2. **Body**: Elaborate on each key point from the summary. Use relevant examples, anecdotes, or data to enrich the content and provide valuable insights. Ensure each point transitions smoothly to the next.
3. **Tone and Style**: Maintain a consistent tone that resonates with a broad audience while providing detailed insights that enthusiasts will appreciate. Be informative yet engaging.
4. **Audience Engagement**: Incorporate questions, calls-to-action, or prompts for comments to engage the audience and encourage interaction. Make the reader feel involved.
5. **Conclusion**: Summarize the main points of the blog post and offer a final thought or call to action that leaves the reader thinking or motivated to act.
6. **SEO Considerations**: Integrate relevant keywords naturally throughout the post to enhance search engine visibility without compromising the quality and readability of the content.

Ensure the narrative flows logically and cohesively from the introduction to the conclusion, creating an engaging and informative reading experience.
"""

    user_prompt = f"""Using the provided summary below, generate a comprehensive blog post. Focus on expanding each point with detailed insights and context. Ensure the narrative flows logically from the introduction to the conclusion, creating an engaging and informative reading experience.

---BEGIN SUMMARY---
{summary}
---END SUMMARY---
"""

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ]

    for attempt in range(retries + 1):
        try:
            response = client.chat.completions.create(
                model="gpt-4o",
                messages=messages,
                max_tokens=1500,
                temperature=0.85
            )
            return response.choices[0].message.content.strip()
        except (APIConnectionError, RateLimitError, APIError) as e:
            logging.error(f"OpenAI API request failed (Attempt {attempt + 1}): {str(e)}")
            if attempt == retries:
                return None
        except Exception as e:
            logging.error(f"An unexpected error occurred (Attempt {attempt + 1}): {str(e)}")
            if attempt == retries:
                return None

def write_blog_post(content, file_number):
    output_filename = f"GPT_4o_Raw_Text_{file_number}.txt"
    output_path = os.path.join(output_directory, output_filename)
    try:
        with open(output_path, 'w', encoding='utf-8') as file:
            file.write(content)
            logging.info(f"Blog post written to {output_path}")
    except Exception as e:
        logging.error(f"Failed to write blog post to {output_path}: {str(e)}")

def main():
    start_time = time.time()
    file_count = 0

    for file_number in range(1, 101):  # Sequentially from 1 to 100
        logging.info(f"Processing file number: {file_number}")
        summary = fetch_summary_from_s3(file_number)
        if summary:
            blog_post = generate_blog_post(summary)
            if blog_post:
                write_blog_post(blog_post, file_number)
                file_count += 1

    elapsed_time = time.time() - start_time
    logging.info(f"Processed {file_count} files in {elapsed_time:.2f} seconds.")

if __name__ == '__main__':
    main()
# Out:
# 2024-05-20 21:08:36,172 - INFO - Processing file number: 1
# 2024-05-20 21:09:01,436 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:09:01,447 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_1.txt
# 2024-05-20 21:09:01,448 - INFO - Processing file number: 2
# 2024-05-20 21:09:21,623 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:09:21,630 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_2.txt
# 2024-05-20 21:09:21,634 - INFO - Processing file number: 3
# 2024-05-20 21:09:40,269 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:09:40,272 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_3.txt
# 2024-05-20 21:09:40,273 - INFO - Processing file number: 4
# 2024-05-20 21:09:57,072 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:09:57,097 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_4.txt
# 2024-05-20 21:09:57,132 - INFO - Processing file number: 5
# 2024-05-20 21:10:44,075 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:10:44,077 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_5.txt
# 2024-05-20 21:10:44,081 - INFO - Processing file number: 6
# 2024-05-20 21:11:02,888 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:11:02,892 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_6.txt
# 2024-05-20 21:11:02,893 - INFO - Processing file number: 7
# 2024-05-20 21:11:18,502 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:11:18,506 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_7.txt
# 2024-05-20 21:11:18,509 - INFO - Processing file number: 8
# 2024-05-20 21:11:43,418 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:11:43,421 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_8.txt
# 2024-05-20 21:11:43,422 - INFO - Processing file number: 9
# 2024-05-20 21:12:01,146 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:12:01,150 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_9.txt
# 2024-05-20 21:12:01,151 - INFO - Processing file number: 10
# 2024-05-20 21:12:16,389 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:12:16,392 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_10.txt
# 2024-05-20 21:12:16,393 - INFO - Processing file number: 11
# 2024-05-20 21:12:40,453 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:12:40,456 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_11.txt
# 2024-05-20 21:12:40,473 - INFO - Processing file number: 12
# 2024-05-20 21:12:58,252 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:12:58,255 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_12.txt
# 2024-05-20 21:12:58,255 - INFO - Processing file number: 13
# 2024-05-20 21:13:23,678 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:13:23,681 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_13.txt
# 2024-05-20 21:13:23,683 - INFO - Processing file number: 14
# 2024-05-20 21:13:41,166 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:13:41,168 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_14.txt
# 2024-05-20 21:13:41,169 - INFO - Processing file number: 15
# 2024-05-20 21:14:01,739 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:14:01,743 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_15.txt
# 2024-05-20 21:14:01,744 - INFO - Processing file number: 16
# 2024-05-20 21:14:22,737 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:14:22,741 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_16.txt
# 2024-05-20 21:14:22,747 - INFO - Processing file number: 17
# 2024-05-20 21:14:38,422 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:14:38,426 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_17.txt
# 2024-05-20 21:14:38,427 - INFO - Processing file number: 18
# 2024-05-20 21:14:56,475 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:14:56,478 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_18.txt
# 2024-05-20 21:14:56,481 - INFO - Processing file number: 19
# 2024-05-20 21:15:16,135 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:15:16,138 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_19.txt
# 2024-05-20 21:15:16,139 - INFO - Processing file number: 20
# 2024-05-20 21:15:38,712 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:15:38,714 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_20.txt
# 2024-05-20 21:15:38,716 - INFO - Processing file number: 21
# 2024-05-20 21:16:12,152 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:16:12,154 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_21.txt
# 2024-05-20 21:16:12,156 - INFO - Processing file number: 22
# 2024-05-20 21:16:33,697 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:16:33,701 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_22.txt
# 2024-05-20 21:16:33,703 - INFO - Processing file number: 23
# 2024-05-20 21:17:04,741 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:17:04,746 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_23.txt
# 2024-05-20 21:17:04,747 - INFO - Processing file number: 24
# 2024-05-20 21:17:21,861 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:17:21,863 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_24.txt
# 2024-05-20 21:17:21,864 - INFO - Processing file number: 25
# 2024-05-20 21:17:41,270 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:17:41,272 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_25.txt
# 2024-05-20 21:17:41,273 - INFO - Processing file number: 26
# 2024-05-20 21:18:11,940 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:18:11,943 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_26.txt
# 2024-05-20 21:18:11,945 - INFO - Processing file number: 27
# 2024-05-20 21:18:43,045 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:18:43,181 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_27.txt
# 2024-05-20 21:18:43,182 - INFO - Processing file number: 28
# 2024-05-20 21:19:00,932 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:19:00,979 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_28.txt
# 2024-05-20 21:19:00,981 - INFO - Processing file number: 29
# 2024-05-20 21:19:25,261 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:19:25,263 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_29.txt
# 2024-05-20 21:19:25,266 - INFO - Processing file number: 30
# 2024-05-20 21:19:44,663 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:19:44,666 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_30.txt
# 2024-05-20 21:19:44,668 - INFO - Processing file number: 31
# 2024-05-20 21:20:03,562 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:20:03,564 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_31.txt
# 2024-05-20 21:20:03,565 - INFO - Processing file number: 32
# 2024-05-20 21:20:22,446 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:20:22,448 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_32.txt
# 2024-05-20 21:20:22,449 - INFO - Processing file number: 33
# 2024-05-20 21:20:41,039 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:20:41,043 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_33.txt
# 2024-05-20 21:20:41,044 - INFO - Processing file number: 34
# 2024-05-20 21:20:57,134 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:20:57,138 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_34.txt
# 2024-05-20 21:20:57,140 - INFO - Processing file number: 35
# 2024-05-20 21:21:22,053 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:21:22,057 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_35.txt
# 2024-05-20 21:21:22,060 - INFO - Processing file number: 36
# 2024-05-20 21:21:40,054 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:21:40,058 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_36.txt
# 2024-05-20 21:21:40,060 - INFO - Processing file number: 37
# 2024-05-20 21:21:57,475 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:21:57,478 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_37.txt
# 2024-05-20 21:21:57,480 - INFO - Processing file number: 38
# 2024-05-20 21:22:13,928 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:22:13,931 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_38.txt
# 2024-05-20 21:22:13,932 - INFO - Processing file number: 39
# 2024-05-20 21:22:33,168 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:22:33,171 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_39.txt
# 2024-05-20 21:22:33,179 - INFO - Processing file number: 40
# 2024-05-20 21:22:50,015 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:22:50,021 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_40.txt
# 2024-05-20 21:22:50,023 - INFO - Processing file number: 41
# 2024-05-20 21:23:06,378 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:23:06,381 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_41.txt
# 2024-05-20 21:23:06,382 - INFO - Processing file number: 42
# 2024-05-20 21:23:22,731 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:23:22,735 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_42.txt
# 2024-05-20 21:23:22,736 - INFO - Processing file number: 43
# 2024-05-20 21:23:45,058 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:23:45,064 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_43.txt
# 2024-05-20 21:23:45,067 - INFO - Processing file number: 44
# 2024-05-20 21:24:08,879 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:24:08,891 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_44.txt
# 2024-05-20 21:24:08,895 - INFO - Processing file number: 45
# 2024-05-20 21:24:29,471 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:24:29,474 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_45.txt
# 2024-05-20 21:24:29,475 - INFO - Processing file number: 46
# 2024-05-20 21:24:54,319 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:24:54,363 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_46.txt
# 2024-05-20 21:24:54,364 - INFO - Processing file number: 47
# 2024-05-20 21:25:12,145 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:25:12,148 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_47.txt
# 2024-05-20 21:25:12,149 - INFO - Processing file number: 48
# 2024-05-20 21:25:43,409 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:25:43,434 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_48.txt
# 2024-05-20 21:25:43,477 - INFO - Processing file number: 49
# 2024-05-20 21:26:01,149 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:26:01,152 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_49.txt
# 2024-05-20 21:26:01,154 - INFO - Processing file number: 50
# 2024-05-20 21:26:24,459 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:26:24,465 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_50.txt
# 2024-05-20 21:26:24,467 - INFO - Processing file number: 51
# 2024-05-20 21:26:46,995 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:26:46,997 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_51.txt
# 2024-05-20 21:26:46,998 - INFO - Processing file number: 52
# 2024-05-20 21:27:11,056 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:27:11,064 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_52.txt
# 2024-05-20 21:27:11,068 - INFO - Processing file number: 53
# 2024-05-20 21:27:33,901 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:27:33,904 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_53.txt
# 2024-05-20 21:27:33,905 - INFO - Processing file number: 54
# 2024-05-20 21:27:57,188 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:27:57,191 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_54.txt
# 2024-05-20 21:27:57,192 - INFO - Processing file number: 55
# 2024-05-20 21:28:15,666 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:28:15,669 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_55.txt
# 2024-05-20 21:28:15,670 - INFO - Processing file number: 56
# 2024-05-20 21:28:37,584 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:28:37,587 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_56.txt
# 2024-05-20 21:28:37,588 - INFO - Processing file number: 57
# 2024-05-20 21:28:57,679 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:28:57,681 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_57.txt
# 2024-05-20 21:28:57,686 - INFO - Processing file number: 58
# 2024-05-20 21:29:15,118 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:29:15,120 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_58.txt
# 2024-05-20 21:29:15,122 - INFO - Processing file number: 59
# 2024-05-20 21:29:35,614 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:29:35,616 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_59.txt
# 2024-05-20 21:29:35,618 - INFO - Processing file number: 60
# 2024-05-20 21:29:53,515 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:29:53,520 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_60.txt
# 2024-05-20 21:29:53,523 - INFO - Processing file number: 61
# 2024-05-20 21:30:25,541 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:30:25,547 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_61.txt
# 2024-05-20 21:30:25,549 - INFO - Processing file number: 62
# 2024-05-20 21:30:51,666 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:30:51,670 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_62.txt
# 2024-05-20 21:30:51,671 - INFO - Processing file number: 63
# 2024-05-20 21:31:11,977 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:31:11,979 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_63.txt
# 2024-05-20 21:31:11,980 - INFO - Processing file number: 64
# 2024-05-20 21:31:36,081 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:31:36,083 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_64.txt
# 2024-05-20 21:31:36,084 - INFO - Processing file number: 65
# 2024-05-20 21:31:52,546 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:31:52,549 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_65.txt
# 2024-05-20 21:31:52,550 - INFO - Processing file number: 66
# 2024-05-20 21:32:10,788 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:32:10,795 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_66.txt
# 2024-05-20 21:32:10,803 - INFO - Processing file number: 67
# 2024-05-20 21:32:35,263 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:32:35,265 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_67.txt
# 2024-05-20 21:32:35,266 - INFO - Processing file number: 68
# 2024-05-20 21:32:58,846 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:32:58,849 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_68.txt
# 2024-05-20 21:32:58,850 - INFO - Processing file number: 69
# 2024-05-20 21:33:19,041 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:33:19,043 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_69.txt
# 2024-05-20 21:33:19,044 - INFO - Processing file number: 70
# 2024-05-20 21:33:37,744 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:33:37,746 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_70.txt
# 2024-05-20 21:33:37,748 - INFO - Processing file number: 71
# 2024-05-20 21:33:55,420 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:33:55,422 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_71.txt
# 2024-05-20 21:33:55,423 - INFO - Processing file number: 72
# 2024-05-20 21:34:15,332 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:34:15,335 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_72.txt
# 2024-05-20 21:34:15,336 - INFO - Processing file number: 73
# 2024-05-20 21:34:46,174 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:34:46,506 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_73.txt
# 2024-05-20 21:34:46,521 - INFO - Processing file number: 74
# 2024-05-20 21:35:18,339 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:35:18,341 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_74.txt
# 2024-05-20 21:35:18,343 - INFO - Processing file number: 75
# 2024-05-20 21:35:47,456 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:35:47,459 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_75.txt
# 2024-05-20 21:35:47,461 - INFO - Processing file number: 76
# 2024-05-20 21:36:08,863 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:36:08,866 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_76.txt
# 2024-05-20 21:36:08,869 - INFO - Processing file number: 77
# 2024-05-20 21:36:29,835 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:36:29,840 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_77.txt
# 2024-05-20 21:36:29,841 - INFO - Processing file number: 78
# 2024-05-20 21:36:51,264 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:36:51,266 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_78.txt
# 2024-05-20 21:36:51,268 - INFO - Processing file number: 79
# 2024-05-20 21:37:11,039 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:37:11,043 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_79.txt
# 2024-05-20 21:37:11,044 - INFO - Processing file number: 80
# 2024-05-20 21:37:49,077 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:37:49,086 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_80.txt
# 2024-05-20 21:37:49,087 - INFO - Processing file number: 81
# 2024-05-20 21:38:05,523 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:38:05,535 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_81.txt
# 2024-05-20 21:38:05,548 - INFO - Processing file number: 82
# 2024-05-20 21:38:36,213 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:38:36,215 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_82.txt
# 2024-05-20 21:38:36,217 - INFO - Processing file number: 83
# 2024-05-20 21:39:01,237 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:39:01,242 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_83.txt
# 2024-05-20 21:39:01,246 - INFO - Processing file number: 84
# 2024-05-20 21:39:20,771 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:39:20,906 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_84.txt
# 2024-05-20 21:39:20,908 - INFO - Processing file number: 85
# 2024-05-20 21:39:44,010 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:39:44,013 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_85.txt
# 2024-05-20 21:39:44,018 - INFO - Processing file number: 86
# 2024-05-20 21:40:04,328 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:40:04,330 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_86.txt
# 2024-05-20 21:40:04,331 - INFO - Processing file number: 87
# 2024-05-20 21:40:30,630 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:40:30,635 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_87.txt
# 2024-05-20 21:40:30,636 - INFO - Processing file number: 88
# 2024-05-20 21:40:53,058 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:40:53,060 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_88.txt
# 2024-05-20 21:40:53,062 - INFO - Processing file number: 89
# 2024-05-20 21:41:13,906 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:41:13,909 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_89.txt
# 2024-05-20 21:41:13,910 - INFO - Processing file number: 90
# 2024-05-20 21:41:27,447 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:41:27,450 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_90.txt
# 2024-05-20 21:41:27,451 - INFO - Processing file number: 91
# 2024-05-20 21:41:59,269 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:41:59,519 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_91.txt
# 2024-05-20 21:41:59,520 - INFO - Processing file number: 92
# 2024-05-20 21:42:21,825 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:42:21,827 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_92.txt
# 2024-05-20 21:42:21,828 - INFO - Processing file number: 93
# 2024-05-20 21:42:46,842 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:42:46,890 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_93.txt
# 2024-05-20 21:42:46,901 - INFO - Processing file number: 94
# 2024-05-20 21:43:02,452 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:43:02,456 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_94.txt
# 2024-05-20 21:43:02,457 - INFO - Processing file number: 95
# 2024-05-20 21:43:22,037 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:43:22,042 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_95.txt
# 2024-05-20 21:43:22,044 - INFO - Processing file number: 96
# 2024-05-20 21:43:40,015 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:43:40,018 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_96.txt
# 2024-05-20 21:43:40,020 - INFO - Processing file number: 97
# 2024-05-20 21:44:01,067 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:44:01,069 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_97.txt
# 2024-05-20 21:44:01,076 - INFO - Processing file number: 98
# 2024-05-20 21:44:26,653 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:44:26,656 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_98.txt
# 2024-05-20 21:44:26,657 - INFO - Processing file number: 99
# 2024-05-20 21:44:43,558 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:44:43,561 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_99.txt
# 2024-05-20 21:44:43,562 - INFO - Processing file number: 100
# 2024-05-20 21:45:03,922 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-20 21:45:03,924 - INFO - Blog post written to 4o Blog Raw Text Matt/GPT_4o_Raw_Text_100.txt
# 2024-05-20 21:45:03,926 - INFO - Processed 100 files in 2187.75 seconds.
